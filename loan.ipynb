# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepeshMadane/Machine-learning-/blob/main/loan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              61 non-null     int64
#  1   gender           61 non-null     object
#  2   occupation       61 non-null     object
#  3   education_level  61 non-null     object
#  4   marital_status   61 non-null     object
#  5   income           61 non-null     int64
#  6   credit_score     61 non-null     int64
#  7   loan_status      61 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 3.9+ KB

# %%
df.head()
# Out:
#    age  gender  occupation education_level marital_status  income  \
# 0   32    Male    Engineer      Bachelor's        Married   85000
# 1   45  Female     Teacher        Master's         Single   62000
# 2   28    Male     Student     High School         Single   25000
# 3   51  Female     Manager      Bachelor's        Married  105000
# 4   36    Male  Accountant      Bachelor's        Married   75000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved
# 2           590      Denied
# 3           780    Approved
# 4           710    Approved

# %%
df['education_level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'High School', "Associate's", 'Doctoral'],
#       dtype=object)

# %%
df['gender'] = df['gender'].map({'Male':0,'Female':1})
df['gender'] = df['gender'].astype(float)

# %%
df.head()
# Out:
#    age  gender  occupation education_level marital_status  income  \
# 0   32     0.0    Engineer      Bachelor's        Married   85000
# 1   45     1.0     Teacher        Master's         Single   62000
# 2   28     0.0     Student     High School         Single   25000
# 3   51     1.0     Manager      Bachelor's        Married  105000
# 4   36     0.0  Accountant      Bachelor's        Married   75000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved
# 2           590      Denied
# 3           780    Approved
# 4           710    Approved

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['education_level'] = le.fit_transform(df['education_level'])

# %%
df.head()
# Out:
#    age  gender  occupation  education_level marital_status  income  \
# 0   32     0.0    Engineer                1        Married   85000
# 1   45     1.0     Teacher                4         Single   62000
# 2   28     0.0     Student                3         Single   25000
# 3   51     1.0     Manager                1        Married  105000
# 4   36     0.0  Accountant                1        Married   75000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved
# 2           590      Denied
# 3           780    Approved
# 4           710    Approved

# %%
df['occupation'].unique()
# Out:
# array(['Engineer', 'Teacher', 'Student', 'Manager', 'Accountant', 'Nurse',
#        'Lawyer', 'Artist', 'IT', 'Doctor', 'Consultant', 'Analyst',
#        'Salesman', 'Marketing', 'Architect', 'Designer', 'Pharmacist',
#        'Researcher', 'Professor', 'Pilot', 'Receptionist', 'Banker',
#        'Writer', 'Chef', 'Veterinarian', 'Sales', 'HR', 'Electrician',
#        'Realtor', 'Photographer', 'Editor', 'Programmer', 'Dentist',
#        'Musician', 'Psychologist', 'Server', 'Software', 'Stylist'],
#       dtype=object)

# %%
df['occupation'] = le.fit_transform(df['occupation'])

# %%
df['occupation'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61 entries, 0 to 60
# Series name: occupation
# Non-Null Count  Dtype
# --------------  -----
# 61 non-null     int64
# dtypes: int64(1)
# memory usage: 616.0 bytes

# %%
df['marital_status'] = le.fit_transform(df['marital_status'])

# %%
df.head()
# Out:
#    age  gender  occupation  education_level  marital_status  income  \
# 0   32     0.0          12                1               0   85000
# 1   45     1.0          35                4               1   62000
# 2   28     0.0          33                3               1   25000
# 3   51     1.0          16                1               0  105000
# 4   36     0.0           0                1               0   75000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved
# 2           590      Denied
# 3           780    Approved
# 4           710    Approved

# %%
X = df.drop(columns=['loan_status'])
y = df['loan_status']

# %%
X
# Out:
#     age  gender  occupation  education_level  marital_status  income  \
# 0    32     0.0          12                1               0   85000
# 1    45     1.0          35                4               1   62000
# 2    28     0.0          33                3               1   25000
# 3    51     1.0          16                1               0  105000
# 4    36     0.0           0                1               0   75000
# ..  ...     ...         ...              ...             ...     ...
# 56   39     0.0           2                4               0  100000
# 57   25     1.0          27                3               1   32000
# 58   43     0.0           4                1               0   95000
# 59   30     1.0          37                4               1   55000
# 60   38     0.0           5                0               0   65000
#
#     credit_score
# 0            720
# 1            680
# 2            590
# 3            780
# 4            710
# ..           ...
# 56           770
# 57           570
# 58           760
# 59           650
# 60           700
#
# [61 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#     age  gender  occupation  education_level  marital_status  income  \
# 41   30     1.0          35                4               1   58000
# 33   47     1.0           7                2               0  140000
# 43   28     1.0          19                0               1   50000
# 49   27     1.0           3                1               1   35000
# 7    29     1.0           3                1               1   38000
#
#     credit_score
# 41           670
# 33           810
# 43           660
# 49           600
# 7            620

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[9 1]
#  [0 3]]

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 100.00 %
# Standard Deviation: 0.00 %

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.9231
